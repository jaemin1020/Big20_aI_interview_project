# %%
import pandas as pd
import json

# preprocessed_data.json 파일을 데이터프레임으로 변환
file_path = 'preprocessed_data.json'

with open(file_path, 'r', encoding='utf-8') as f:
    data = json.load(f)

df = pd.DataFrame(data)

# 데이터프레임 확인
df.head()

# %%
# 엑셀 파일로 저장하고 싶은 경우 아래 주석을 해제하세요
# df.to_excel('preprocessed_data.xlsx', index=False)
